# %%
import requests

# %%
import pandas as pd
import numpy as np

# %%
import json

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Get all network information
x = requests.get('http://api.citybik.es/v2/networks')
x.status_code
# Out:
# 200

# %%
networks = json.loads(x.content)
networks
# Out:
# {'networks': [{'company': ['Careem'],
#    'gbfs_href': 'https://dubai.publicbikesystem.net/customer/gbfs/v2/en/gbfs.json',
#    'href': '/v2/networks/abu-dhabi-careem-bike',
#    'id': 'abu-dhabi-careem-bike',
#    'location': {'city': 'Abu Dhabi',
#     'country': 'AE',
#     'latitude': 24.4866,
#     'longitude': 54.3728},
#    'name': 'Abu Dhabi Careem BIKE'},
#   {'company': ['PBSC Urban Solutions'],
#    'gbfs_href': 'https://saguenay.publicbikesystem.net/customer/gbfs/v2/gbfs.json',
#    'href': '/v2/networks/acces-velo-saguenay',
#    'id': 'acces-velo-saguenay',
#    'location': {'city': 'Saguenay',
#     'country': 'CA',
#     'latitude': 48.433333,
#     'longitude': -71.083333},
#    'name': 'Accès Vélo'},
#   {'company': ['阿克苏公共服务'],
#    'href': '/v2/networks/aksu',
#    'id': 'aksu',
#    'location': {'city': '阿克苏市 (Aksu City)',
#     'country': 'CN',
#     'latitude': 41.1664,
#     'longitude': 80.2617},
#    'name': 'Aksu'},
#   {'company': ['Comunicare S.r.l.'],
# ...

# %%
# Only need some of the fields 
n_limited = requests.get('http://api.citybik.es/v2/networks', params={'fields':'id,name'})
networks_limited_json = json.loads(n_limited.content)

networks_df = pd.DataFrame.from_dict(networks_limited_json.pop('networks'))
networks_df.head(10)
# Out:
#                       id                   name
# 0  abu-dhabi-careem-bike  Abu Dhabi Careem BIKE
# 1    acces-velo-saguenay             Accès Vélo
# 2                   aksu                   Aksu
# 3                   alba                   Alba
# 4               albabici               AlbaBici
# 5                 algira                 AlGira
# 6             almatybike             Almatybike
# 7     alsa-nextbike-leon     Alsa nextbike León
# 8             ambici-amb                 Ambici
# 9        ambici-badalona                 Ambici

# %%
# Pull Station data for DC's Bike Share, Capital Bikeshare
c = requests.get('http://api.citybik.es/v2/networks/capital-bikeshare', params={'fields':'stations'})
cabi = json.loads(c.content)
# cabi
cabi_stations = pd.DataFrame.from_dict(cabi.pop('network').pop('stations'))
cabi_stations.head(10)
# Out:
#    empty_slots                                              extra  free_bikes  \
# 0           10  {'uid': '082623bf-1f3f-11e7-bf6b-3863bb334450'...           4
# 1            6  {'uid': '08253b95-1f3f-11e7-bf6b-3863bb334450'...           9
# 2           14  {'uid': '066fd95e-0d37-4eea-a027-88c04277bb9d'...           0
# 3            5  {'uid': '082569e6-1f3f-11e7-bf6b-3863bb334450'...           2
# 4           31  {'uid': '08247e59-1f3f-11e7-bf6b-3863bb334450'...           1
# 5            8  {'uid': '1e196ee1-daa4-4fa6-b6f8-197b31e6d170'...           7
# 6            9  {'uid': '0824e72a-1f3f-11e7-bf6b-3863bb334450'...          19
# 7            2  {'uid': '1939176485434179842', 'renting': 1, '...          12
# 8           12  {'uid': 'b053927b-0761-40d0-a3ff-8a63fa1c7141'...           0
# 9           18  {'uid': '343aa3f9-0b2f-4599-9854-81cbc04577f4'...           1
#
#                                  id   latitude  longitude  \
# ...

# %%
# stations with the most bikes
cabi_stations.sort_values('free_bikes', ascending=False).head(10)
# Out:
#      empty_slots                                              extra  \
# 356            4  {'uid': '08249dad-1f3f-11e7-bf6b-3863bb334450'...
# 402           15  {'uid': '0824d0c6-1f3f-11e7-bf6b-3863bb334450'...
# 69             3  {'uid': '0824c80d-1f3f-11e7-bf6b-3863bb334450'...
# 215            2  {'uid': '0824a623-1f3f-11e7-bf6b-3863bb334450'...
# 238            9  {'uid': '0824c69b-1f3f-11e7-bf6b-3863bb334450'...
# 585           14  {'uid': '08250371-1f3f-11e7-bf6b-3863bb334450'...
# 646            9  {'uid': '0824c604-1f3f-11e7-bf6b-3863bb334450'...
# 660            6  {'uid': '0825fca2-1f3f-11e7-bf6b-3863bb334450'...
# 693           11  {'uid': '5f71434d-dc5c-45ff-8219-708a3d9a0691'...
# 140           18  {'uid': '08249b7f-1f3f-11e7-bf6b-3863bb334450'...
#
#      free_bikes                                id   latitude  longitude  \
# 356          43  6e37eab19301e2a4f8723d01debd2fc9  38.893028 -77.026013
# 402          38  7a03f9cbe938f3be78aa94c699049942  38.896960 -77.004930
# ...

# %%
# stations with the most parking spots
cabi_stations.sort_values('empty_slots', ascending=False).head(10)
# Out:
#      empty_slots                                              extra  \
# 539           37  {'uid': '08247522-1f3f-11e7-bf6b-3863bb334450'...
# 561           33  {'uid': '0824c309-1f3f-11e7-bf6b-3863bb334450'...
# 683           32  {'uid': '0824f8a2-1f3f-11e7-bf6b-3863bb334450'...
# 4             31  {'uid': '08247e59-1f3f-11e7-bf6b-3863bb334450'...
# 540           31  {'uid': '08256670-1f3f-11e7-bf6b-3863bb334450'...
# 427           30  {'uid': '0824749f-1f3f-11e7-bf6b-3863bb334450'...
# 403           30  {'uid': '0824d0c6-1f3f-11e7-bf6b-3863bb334450'...
# 741           30  {'uid': '08247a21-1f3f-11e7-bf6b-3863bb334450'...
# 709           29  {'uid': '0824c229-1f3f-11e7-bf6b-3863bb334450'...
# 693           28  {'uid': '5f71434d-dc5c-45ff-8219-708a3d9a0691'...
#
#      free_bikes                                id   latitude  longitude  \
# 539           0  a5d0ef943e552cc78205d5f8ad7f5731  38.929464 -77.027822
# 561           0  af76d115cb01553e9b728477c24e936a  38.894832 -76.987633
# ...

# %%
# Capital coordinates -  38.889921, -77.011001
# Only want stations in northwest of the capital
nw_cabi_stations = cabi_stations[(cabi_stations['latitude'] > 38.889921) & (cabi_stations['longitude'] < -77.011001) ]
nw_cabi_stations['id'].count()
# Out:
# 366

# %%
nw_cabi_stations.sort_values('free_bikes', ascending=False).head(10)
# Out:
#      empty_slots                                              extra  \
# 238            6  {'uid': '0824c69b-1f3f-11e7-bf6b-3863bb334450'...
# 215            0  {'uid': '0824a623-1f3f-11e7-bf6b-3863bb334450'...
# 646            8  {'uid': '0824c604-1f3f-11e7-bf6b-3863bb334450'...
# 98             2  {'uid': '08254037-1f3f-11e7-bf6b-3863bb334450'...
# 660            4  {'uid': '0825fca2-1f3f-11e7-bf6b-3863bb334450'...
# 357           18  {'uid': '08249dad-1f3f-11e7-bf6b-3863bb334450'...
# 656            1  {'uid': '08249aa2-1f3f-11e7-bf6b-3863bb334450'...
# 437            1  {'uid': '0824a28b-1f3f-11e7-bf6b-3863bb334450'...
# 69            13  {'uid': '0824c80d-1f3f-11e7-bf6b-3863bb334450'...
# 111            2  {'uid': 'b554d2fc-8912-4730-b2cb-9a3e1a96b223'...
#
#      free_bikes                                id   latitude  longitude  \
# 238          35  497a312729b49320919ff090eb2b339f  38.894514 -77.031617
# 215          32  42549bd7d771a9c9a08f1293bdd15cd4  38.902801 -77.062819
# ...

# %%
nw_cabi_stations['Total Slots'] = nw_cabi_stations['free_bikes'] + nw_cabi_stations['empty_slots']

nw_cabi_stations.loc[:,['name','Total Slots','free_bikes','empty_slots']].sort_values('Total Slots', ascending=False).head(10)
# Out:
#                                         name  Total Slots  free_bikes  \
# 357            10th St & Constitution Ave NW           47          29
# 514                           21st & I St NW           45          21
# 238  14th & D St NW / John A Wilson Building           41          35
# 646            Metro Center / 12th & G St NW           39          31
# 69          17th & K St NW / Farragut Square           38          25
# 541                 16th & K St NW/BLM Plaza           38          13
# 539                      11th & Kenyon St NW           37           0
# 745            19th St & Constitution Ave NW           35          15
# 364            20th & O St NW / Dupont South           34          19
# 86                  New Jersey Ave & F St NW           33          21
#
#      empty_slots
# 357           18
# 514           24
# 238            6
# 646            8
# 69            13
# 541           25
# 539           37
# 745           20
# 364           15
# ...
